# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.stats import gaussian_kde
from scipy.integrate import simps

# %%
class PolymerMotion:
    def __init__(self, num_particles, spring_constants, mass=1.0, dt=0.01, total_time=10):
        self.num_particles = num_particles
        self.spring_constants = spring_constants
        self.mass = np.full(num_particles, mass)  # Mass for each particle
        self.dt = dt
        self.total_time = total_time

        # Initialize positions and velocities
        self.positions = np.random.rand(num_particles, 2)  # Random initial positions in 2D
        self.velocities = np.zeros((num_particles, 2))  # Start with zero velocity
        self.time_steps = int(total_time / dt)  # Total number of time steps
        self.trajectory = np.zeros((self.time_steps, num_particles, 2))  # Store trajectory

    def forces(self, positions):
        # Calculate the spring forces
        F = np.zeros((self.num_particles, 2))
        for i in range(self.num_particles):
            for j in range(i + 1, self.num_particles):
                # Calculate the spring force based on Hooke's law
                displacement = positions[j] - positions[i]
                distance = np.linalg.norm(displacement)
                if distance > 0:
                    spring_force = self.spring_constants[i] * displacement / distance
                    F[i] += spring_force
                    F[j] -= spring_force  # Action-Reaction pair
        return F

    def motion_equations(self, y, t):
        # Unpack positions and velocities from the state vector y
        positions = y[:self.num_particles * 2].reshape((self.num_particles, 2))
        velocities = y[self.num_particles * 2:].reshape((self.num_particles, 2))

        # Calculate forces
        F = self.forces(positions)

        # Add damping force (assumed uniform damping coefficient)
        damping_coefficient = 0.2  # Adjust this value as needed
        damping_force = -damping_coefficient * velocities

        # Equations of motion: d(position)/dt = velocity, d(velocity)/dt = (force + damping) / mass
        dydt = np.zeros_like(y)
        dydt[:self.num_particles * 2] = velocities.flatten()  # d(position)/dt = velocity
        dydt[self.num_particles * 2:] = ((F + damping_force) / self.mass[:, None]).flatten()  # d(velocity)/dt = (force + damping) / mass

        return dydt

    def simulate(self):
        # Initial state vector: [positions, velocities]
        initial_conditions = np.hstack((self.positions.flatten(), self.velocities.flatten()))
        t = np.linspace(0, self.total_time, self.time_steps)

        # Integrate the equations of motion
        solution = odeint(self.motion_equations, initial_conditions, t)

        # Extract positions from the solution
        positions = solution[:, :self.num_particles * 2].reshape((-1, self.num_particles, 2))
        self.trajectory = positions  # Store the trajectory
        return t, positions

    def generate_transition_matrix(self):
        # Create a transition matrix based on the entire trajectory
        transition_matrix = np.zeros((self.num_particles, self.num_particles))

        # Calculate cumulative displacement over the trajectory
        cumulative_displacements = np.zeros((self.num_particles, self.num_particles))
        for t in range(1, self.time_steps):
            for i in range(self.num_particles):
                for j in range(self.num_particles):
                    displacement = np.linalg.norm(self.trajectory[t, i] - self.trajectory[t - 1, j])
                    # Track cumulative displacements for self and inter-particle transitions
                    cumulative_displacements[i, j] += displacement

        # Use cumulative displacement to adjust transition probabilities
        for i in range(self.num_particles):
            row_sum = cumulative_displacements[i].sum()
            if row_sum == 0:
                transition_matrix[i] = np.ones(self.num_particles) / self.num_particles
            else:
                for j in range(self.num_particles):
                    # The smaller the displacement, the higher the transition probability
                    if cumulative_displacements[i, j] > 0:
                        transition_matrix[i, j] = 1 / cumulative_displacements[i, j]

        # Normalize rows to sum to 1
        row_sums = transition_matrix.sum(axis=1)
        for i in range(self.num_particles):
            if row_sums[i] > 0:
                transition_matrix[i] /= row_sums[i]
            else:
                transition_matrix[i] = np.ones(self.num_particles) / self.num_particles

        return transition_matrix

    def sample_random_walk(self, transition_matrix, num_steps, initial_state=0):
        state = initial_state
        visited_states = [state]

        for _ in range(num_steps):
            state = np.random.choice(self.num_particles, p=transition_matrix[state])
            visited_states.append(state)

        return visited_states

    def plot_trajectories(self):
        # Plot the trajectories of particles as a function of time
        time = np.linspace(0, self.total_time, self.time_steps)
        plt.figure(figsize=(12, 6))

        for i in range(self.num_particles):
            plt.plot(time, self.trajectory[:, i, 0], label=f'Particle {i+1} X Position', linestyle='-')
            plt.plot(time, self.trajectory[:, i, 1], label=f'Particle {i+1} Y Position', linestyle='--')

        plt.title('Trajectories of Particles Over Time')
        plt.xlabel('Time')
        plt.ylabel('Position')
        plt.legend()
        plt.grid()
        plt.show()
        
    def compute_kde(self, visited_states):
        # Compute the underlying probability distribution using KDE
        kde = gaussian_kde(visited_states)

        # Set x-axis range from -5.0 to a large number to simulate infinity
        X = np.linspace(-5.0, 100, 1000)  # X ranges from 0 to 100 as a proxy for infinity
        P_X = kde(X)
        
        # Normalize the area under the curve
        area_under_curve = simps(P_X, X)  # Integrating the probability distribution
        print(f"Area under the curve (should be ~1 for normalization): {area_under_curve}")

        return X, P_X

    def plot_probability_distribution(self, X, P_X):
        # Plot P(X) vs X
        plt.figure(figsize=(8, 6))
        plt.plot(X, P_X, label='Estimated Probability Distribution')
        plt.title('Probability Distribution Estimated from the Random Walk')
        plt.xlabel('State (X)')
        plt.ylabel('P(X)')
        plt.xlim(-2, 7)  # X-axis from 0 to a large value
        plt.grid(True)
        plt.legend()
        plt.show()

# %%
polymer = PolymerMotion(num_particles=5, spring_constants=np.random.rand(5))
polymer.simulate()
transition_matrix = polymer.generate_transition_matrix()

# %%
print(transition_matrix)
# Out:
# [[0.92510366 0.01958694 0.01164928 0.02174887 0.02191125]
#  [0.02691936 0.90875495 0.01725973 0.02348224 0.02358372]
#  [0.0191378  0.02040339 0.92664822 0.01686391 0.01694669]
#  [0.01916389 0.01495179 0.00909809 0.86969503 0.08709119]
#  [0.01888909 0.01470575 0.00896314 0.08598303 0.87145899]]

# %%
polymer.plot_trajectories()

# %%
# Sample the random walk
num_steps = 80
initial_state = 0
visited_states = polymer.sample_random_walk(transition_matrix, num_steps, initial_state)


# Compute and plot probability distribution
X, P_X = polymer.compute_kde(visited_states)
polymer.plot_probability_distribution(X, P_X)
# Out:
# /var/folders/cf/3rb10wvd7l5bcg3nnk3w22000000gn/T/ipykernel_6418/2381212016.py:130: DeprecationWarning: 'scipy.integrate.simps' is deprecated in favour of 'scipy.integrate.simpson' and will be removed in SciPy 1.14.0
#   area_under_curve = simps(P_X, X)  # Integrating the probability distribution
# Area under the curve (should be ~1 for normalization): 0.9999999999986403

# %% [markdown]
# <h2> Use Rejection Sampling to sample from the distribution<h2>

# %%
import numpy as np

def rejection_sampling(X, P_X, num_samples):
    # Normalize P_X to ensure it's a valid probability distribution
    P_X = P_X / np.sum(P_X)  # Ensure that P_X sums to 1

    # Determine the maximum value of the probability distribution for scaling
    max_P_X = np.max(P_X)

    # Initialize the list of accepted samples
    samples = []
    
    while len(samples) < num_samples:
        # Draw a random sample from X
        proposed_state = np.random.choice(X)

        # Draw a uniform random number to determine acceptance
        u = np.random.uniform(0, max_P_X)

        # Find the index of the proposed state
        index = np.where(X == proposed_state)[0]

        # Ensure the proposed state exists in X
        if index.size == 0:
            continue  # Skip this iteration if proposed_state is not in X

        # Acceptance condition
        if u < P_X[index[0]]:
            samples.append(proposed_state)

    return np.array(samples)

# %%
# Sampling usage
samples = rejection_sampling(X, P_X, num_samples=1000)

# %%
#Scale samples

import numpy as np

def scale_samples(samples, lower_limit, upper_limit):
    """
    Rescale the samples to lie within the given lower and upper limits.

    Parameters:
        samples (np.ndarray): The samples to be rescaled.
        lower_limit (float): The lower limit for scaling.
        upper_limit (float): The upper limit for scaling.

    Returns:
        np.ndarray: Rescaled samples.
    """
    # Find the current min and max of the samples
    min_sample = np.min(samples)
    max_sample = np.max(samples)

    # Rescale the samples to the new range [lower_limit, upper_limit]
    scaled_samples = lower_limit + (samples - min_sample) * (upper_limit - lower_limit) / (max_sample - min_sample)

    return scaled_samples

# %%
low=0
up=1
scaled_samples=scale_samples(samples, low, up)

# %%
# Plotting samples
plt.figure(figsize=(10, 6))
plt.hist(scaled_samples, bins=50, density=False, label='Samples', color='orange', alpha=0.5)
plt.title('Samples from Rejection-Sampling')
plt.xlabel('X')
plt.xlim(low,up)
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <h2> Maximum Entropy(MaxEnt) Ansatz <h2>

# %%
import numpy as np
from scipy.optimize import minimize
from scipy.integrate import quad
import matplotlib.pyplot as plt

# Step 1: Assume `scaled_samples` contains your wait time samples
# For example purposes, let's generate some synthetic data
# (Replace this with your actual wait time samples)
np.random.seed(0)

# Step 2: Calculate the empirical mean of the samples
mean_empirical = np.mean(scaled_samples)

# Step 3: Define the negative entropy for the exponential distribution
def neg_entropy_exponential(params):
    lambda_param = params[0]  # Lambda (rate parameter)

    # Exponential distribution PDF
    def pdf_exponential(x):
        return lambda_param * np.exp(-lambda_param * x)

    # Calculate the probabilities of the empirical samples
    probabilities = pdf_exponential(scaled_samples)

    # Ensure non-zero probabilities to avoid log(0) issues
    probabilities[probabilities <= 0] = 1e-12

    # Calculate the entropy (negative log-likelihood)
    entropy = -np.mean(np.log(probabilities))

    return entropy

# Step 4: Optimize to find the best lambda
initial_guess = [1.0]  # Starting guess for lambda
result = minimize(neg_entropy_exponential, initial_guess)

# Step 5: Output the optimized parameter
if result.success:
    optimized_lambda = result.x[0]
    print(f"Optimized lambda: {optimized_lambda:.4f}")

    # Calculate the mean of the fitted distribution
    fitted_mean = 1 / optimized_lambda
    print(f"Mean of the fitted distribution: {fitted_mean:.4f}")
    print("Empirical mean : "+str(mean_empirical))

else:
    print("Optimization failed.")

# Step 6: Create a fitted PDF with the optimized lambda
def fitted_pdf(x):
    return optimized_lambda * np.exp(-optimized_lambda * x)

# Step 7: Check normalization of the fitted PDF
normalization_factor, _ = quad(fitted_pdf, 0, np.inf)

# Normalization check
print(f"Normalization factor (integral of PDF): {normalization_factor:.4f}")

# Define normalized PDF
def normalized_fitted_pdf(x):
    return fitted_pdf(x) / normalization_factor

# Step 8: Generate x values for plotting
x_values = np.linspace(0, np.max(scaled_samples), 1000)
fitted_pdf_values = normalized_fitted_pdf(x_values)

# Plot the fitted PDF
plt.plot(x_values, fitted_pdf_values, label=f"Fitted Exponential: $\\lambda$={optimized_lambda:.2f}", color='orange')
plt.title('Fitting an Exponential Distribution (MaxEnt)')
plt.xlabel('Time')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Optimized lambda: 1.9345
# Mean of the fitted distribution: 0.5169
# Empirical mean : 0.516925
# Normalization factor (integral of PDF): 1.0000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2> (Optional) : Agent based model of resource trading based on resource procurement wait-times generated from the maximum-entropy distribution <h2>

# %%
import numpy as np
from mesa import Agent, Model
from mesa.time import RandomActivation
import matplotlib.pyplot as plt

# %%
from mesa import Agent, Model
from mesa.time import RandomActivation
import numpy as np

# Define the agent
class ResourceAgent(Agent):
    """ An agent that waits for resources based on a fitted exponential distribution. """
    
    def __init__(self, unique_id, model, lambda_param):
        super().__init__(unique_id, model)
        self.lambda_param = lambda_param  # Lambda for the exponential distribution
        self.wait_time = 0  # Time the agent has waited for resources
        self.resources_acquired = 1  # Ensure each agent starts with at least 1 resource
        self.payoff = 0  # Initialize the agent's payoff
        self.trade_delay = 3  # Steps to wait before trading after acquiring a resource
        self.steps_since_last_trade = 0  # Counter for steps since last trade
        self.missed_opportunity_penalty = 0.5  # Penalty for missed resource acquisition

    def step(self):
        """ The agent waits for resources, incrementing its wait time. """
        # Generate a random waiting time based on the exponential distribution
        waiting_time = np.random.exponential(1 / self.lambda_param)
        self.wait_time += waiting_time

        # Check if the agent can acquire a resource
        if self.wait_time >= self.model.resource_threshold:
            self.acquire_resource()
            self.wait_time = 0  # Reset wait time after acquiring a resource
        
        # Trade resources with another agent if enough time has passed
        self.trade_resources()
        
        # Apply missed opportunity penalty if no resources are acquired in a certain timeframe
        if self.steps_since_last_trade >= self.trade_delay and self.resources_acquired <= 1:
            self.payoff -= self.missed_opportunity_penalty
            print(f"Agent {self.unique_id} missed an opportunity! Payoff: {self.payoff}")

    def acquire_resource(self):
        """ The agent acquires a resource from the model. """
        if self.model.resources > 0:  # Check if resources are available
            self.model.resources -= 1  # Decrement available resources
            self.resources_acquired += 1  # Increment resources acquired by this agent
            self.payoff += 1.0  # Increase payoff when acquiring a resource
            self.steps_since_last_trade = 0  # Reset the trade delay counter
            print(f"Agent {self.unique_id} acquired a resource! Total resources: {self.resources_acquired}, Payoff: {self.payoff}")
        else:
            print(f"Agent {self.unique_id} attempted to acquire a resource but none are available.")

    def trade_resources(self):
        """ The agent trades resources with another agent only if enough time has passed. """
        self.steps_since_last_trade += 1

        if self.steps_since_last_trade >= self.trade_delay:
            # Choose a random agent to trade with and ensure it's not the same agent
            other_agent = self.random.choice(self.model.schedule.agents)
            if other_agent.unique_id == self.unique_id:
                return  # Skip the trade if the selected agent is the same as this agent

            # Define trading logic: Ensure no agent goes to zero resources
            if self.resources_acquired > 1 and other_agent.resources_acquired > 0:
                # Trade one resource between agents
                self.resources_acquired -= 1  # Give away a resource
                other_agent.resources_acquired += 1  # Receive a resource
                
                # Penalize the trading agent and reward the receiving agent
                self.payoff -= 0.5  # Decrease payoff for giving away a resource
                other_agent.payoff += 1  # Increase other agent's payoff
                
                print(f"Agent {self.unique_id} traded 1 resource with Agent {other_agent.unique_id}! Payoff: {self.payoff}")

# Define the model
class ResourceManagementModel(Model):
    """ A model with some number of agents. """
    
    def __init__(self, N, lambda_param):
        super().__init__()  # Initialize the Model class properly
        self.num_agents = N
        self.resources = 500  # Initial number of resources available
        self.resource_threshold = 2  # Threshold for resource acquisition
        self.schedule = RandomActivation(self)

        # Create agents
        for i in range(self.num_agents):
            a = ResourceAgent(i, self, lambda_param)
            self.schedule.add(a)

    def step(self):
        """ Advance the model by one step. """
        self.schedule.step()
        print(f"Remaining available resources: {self.resources}")

    def get_agent_resources(self):
        """ Retrieve the resources acquired by each agent. """
        return [agent.resources_acquired for agent in self.schedule.agents]

# %%
# Parameters for the exponential distribution
model = ResourceManagementModel(N=10, lambda_param=optimized_lambda)

# Run the model for a specified number of steps
for i in range(500):
    print(f"Step {i + 1}")
    model.step()
# Out:
# Step 1
# Remaining available resources: 500
# Step 2
# Remaining available resources: 500
# Step 3
# Agent 0 missed an opportunity! Payoff: -0.5
# Agent 5 missed an opportunity! Payoff: -0.5
# Agent 1 missed an opportunity! Payoff: -0.5
# Agent 4 missed an opportunity! Payoff: -0.5
# Agent 2 missed an opportunity! Payoff: -0.5
# Agent 8 missed an opportunity! Payoff: -0.5
# Agent 6 missed an opportunity! Payoff: -0.5
# Agent 9 missed an opportunity! Payoff: -0.5
# Agent 7 missed an opportunity! Payoff: -0.5
# Agent 3 missed an opportunity! Payoff: -0.5
# Remaining available resources: 500
# Step 4
# Agent 3 acquired a resource! Total resources: 2, Payoff: 0.5
# Agent 9 acquired a resource! Total resources: 2, Payoff: 0.5
# Agent 5 acquired a resource! Total resources: 2, Payoff: 0.5
# Agent 0 acquired a resource! Total resources: 2, Payoff: 0.5
# Agent 6 missed an opportunity! Payoff: -1.0
# Agent 1 missed an opportunity! Payoff: -1.0
# Agent 7 missed an opportunity! Payoff: -1.0
# Agent 4 missed an opportunity! Payoff: -1.0
# Agent 8 acquired a resource! Total resources: 2, Payoff: 0.5
# Agent 2 missed an opportunity! Payoff: -1.0
# Remaining available resources: 495
# Step 5
# Agent 4 missed an opportunity! Payoff: -1.5
# Agent 6 missed an opportunity! Payoff: -1.5
# Agent 7 missed an opportunity! Payoff: -1.5
# Agent 1 acquired a resource! Total resources: 2, Payoff: 0.0
# Agent 2 missed an opportunity! Payoff: -1.5
# Remaining available resources: 494
# Step 6
# Agent 4 acquired a resource! Total resources: 2, Payoff: -0.5
# Agent 8 traded 1 resource with Agent 6! Payoff: 0.0
# Agent 8 missed an opportunity! Payoff: -0.5
# Agent 5 acquired a resource! Total resources: 3, Payoff: 1.5
# Agent 6 acquired a resource! Total resources: 3, Payoff: 0.5
# Agent 3 traded 1 resource with Agent 4! Payoff: 0.0
# Agent 3 missed an opportunity! Payoff: -0.5
# Agent 0 traded 1 resource with Agent 2! Payoff: 0.0
# Agent 0 missed an opportunity! Payoff: -0.5
# Agent 7 acquired a resource! Total resources: 2, Payoff: -0.5
# Agent 9 traded 1 resource with Agent 2! Payoff: 0.0
# Agent 9 missed an opportunity! Payoff: -0.5
# Agent 2 acquired a resource! Total resources: 4, Payoff: 1.5
# Remaining available resources: 489
# Step 7
# Agent 0 missed an opportunity! Payoff: -1.0
# Agent 8 missed an opportunity! Payoff: -1.0
# Agent 3 missed an opportunity! Payoff: -1.0
# Agent 1 traded 1 resource with Agent 3! Payoff: -0.5
# Agent 1 missed an opportunity! Payoff: -1.0
# Agent 9 missed an opportunity! Payoff: -1.0
# Remaining available resources: 489
# Step 8
# Agent 7 traded 1 resource with Agent 5! Payoff: -1.0
# Agent 7 missed an opportunity! Payoff: -1.5
# Agent 9 acquired a resource! Total resources: 2, Payoff: 0.0
# Agent 5 traded 1 resource with Agent 7! Payoff: 2.0
# Agent 3 traded 1 resource with Agent 1! Payoff: -0.5
# Agent 3 missed an opportunity! Payoff: -1.0
# Agent 1 traded 1 resource with Agent 9! Payoff: -0.5
# Agent 1 missed an opportunity! Payoff: -1.0
# Agent 6 traded 1 resource with Agent 9! Payoff: 0.0
# Agent 0 missed an opportunity! Payoff: -1.5
# Agent 8 missed an opportunity! Payoff: -1.5
# Agent 2 traded 1 resource with Agent 5! Payoff: 1.0
# Remaining available resources: 488
# Step 9
# Agent 4 traded 1 resource with Agent 7! Payoff: 0.0
# Agent 8 missed an opportunity! Payoff: -2.0
# Agent 5 traded 1 resource with Agent 1! Payoff: 2.5
# Agent 6 traded 1 resource with Agent 8! Payoff: -0.5
# Agent 6 missed an opportunity! Payoff: -1.0
# Agent 1 acquired a resource! Total resources: 3, Payoff: 1.0
# Agent 2 traded 1 resource with Agent 6! Payoff: 0.5
# Agent 3 missed an opportunity! Payoff: -1.5
# Agent 7 acquired a resource! Total resources: 4, Payoff: 1.5
# Agent 0 acquired a resource! Total resources: 2, Payoff: -0.5
# Remaining available resources: 485
# Step 10
# Agent 3 acquired a resource! Total resources: 2, Payoff: -0.5
# Agent 9 traded 1 resource with Agent 2! Payoff: 1.5
# Agent 2 traded 1 resource with Agent 8! Payoff: 1.0
# Agent 4 traded 1 resource with Agent 6! Payoff: -0.5
# Agent 4 missed an opportunity! Payoff: -1.0
# Agent 8 traded 1 resource with Agent 7! Payoff: -0.5
# Agent 6 traded 1 resource with Agent 2! Payoff: 0.5
# Remaining available resources: 484
# Step 11
# Agent 7 traded 1 resource with Agent 9! Payoff: 2.0
# Agent 0 traded 1 resource with Agent 3! Payoff: -1.0
# Agent 0 missed an opportunity! Payoff: -1.5
# Agent 4 missed an opportunity! Payoff: -1.5
# Agent 1 traded 1 resource with Agent 3! Payoff: 0.5
# Agent 9 traded 1 resource with Agent 1! Payoff: 2.0
# Agent 8 acquired a resource! Total resources: 3, Payoff: 0.5
# Agent 6 acquired a resource! Total resources: 3, Payoff: 1.5
# Agent 2 traded 1 resource with Agent 8! Payoff: 1.5
# Agent 5 acquired a resource! Total resources: 4, Payoff: 3.5
# Remaining available resources: 481
# Step 12
# Agent 7 traded 1 resource with Agent 2! Payoff: 1.5
# Agent 3 traded 1 resource with Agent 4! Payoff: 1.0
# Agent 2 acquired a resource! Total resources: 4, Payoff: 3.5
# Agent 0 acquired a resource! Total resources: 2, Payoff: -0.5
# Agent 1 traded 1 resource with Agent 9! Payoff: 1.0
# Agent 9 acquired a resource! Total resources: 5, Payoff: 4.0
# Agent 4 acquired a resource! Total resources: 3, Payoff: 0.5
# Remaining available resources: 477
# Step 13
# Agent 3 traded 1 resource with Agent 2! Payoff: 0.5
# Agent 5 traded 1 resource with Agent 6! Payoff: 3.0
# Agent 8 traded 1 resource with Agent 1! Payoff: 1.0
# Agent 1 traded 1 resource with Agent 2! Payoff: 1.5
# Agent 6 traded 1 resource with Agent 1! Payoff: 2.0
# Agent 7 acquired a resource! Total resources: 4, Payoff: 2.5
# Remaining available resources: 476
# Step 14
# Agent 3 traded 1 resource with Agent 0! Payoff: 0.0
# Agent 3 missed an opportunity! Payoff: -0.5
# Agent 5 acquired a resource! Total resources: 4, Payoff: 4.0
# Agent 1 acquired a resource! Total resources: 4, Payoff: 3.5
# Agent 0 traded 1 resource with Agent 5! Payoff: 0.0
# Agent 8 acquired a resource! Total resources: 4, Payoff: 2.0
# Agent 4 traded 1 resource with Agent 0! Payoff: 0.0
# Agent 2 traded 1 resource with Agent 8! Payoff: 5.0
# Agent 6 traded 1 resource with Agent 1! Payoff: 1.5
# Remaining available resources: 473
# Step 15
# Agent 2 traded 1 resource with Agent 4! Payoff: 4.5
# Agent 0 acquired a resource! Total resources: 4, Payoff: 2.0
# Agent 6 traded 1 resource with Agent 0! Payoff: 1.0
# Agent 6 missed an opportunity! Payoff: 0.5
# Agent 9 acquired a resource! Total resources: 6, Payoff: 5.0
# Agent 3 acquired a resource! Total resources: 2, Payoff: 0.5
# Agent 7 traded 1 resource with Agent 2! Payoff: 2.0
# Remaining available resources: 470
# Step 16
# Agent 6 missed an opportunity! Payoff: 0.0
# Agent 8 traded 1 resource with Agent 0! Payoff: 2.5
# Agent 4 traded 1 resource with Agent 8! Payoff: 0.5
# Agent 5 acquired a resource! Total resources: 6, Payoff: 6.0
# Agent 2 traded 1 resource with Agent 0! Payoff: 5.0
# Agent 1 traded 1 resource with Agent 4! Payoff: 4.0
# Remaining available resources: 469
# Step 17
# Agent 7 traded 1 resource with Agent 0! Payoff: 1.5
# Agent 8 traded 1 resource with Agent 3! Payoff: 3.0
# Agent 0 traded 1 resource with Agent 4! Payoff: 5.5
# Agent 4 traded 1 resource with Agent 9! Payoff: 2.0
# Agent 6 acquired a resource! Total resources: 2, Payoff: 1.0
# Agent 3 traded 1 resource with Agent 2! Payoff: 1.0
# Agent 2 traded 1 resource with Agent 4! Payoff: 5.5
# Agent 1 traded 1 resource with Agent 0! Payoff: 3.5
# Agent 9 traded 1 resource with Agent 7! Payoff: 5.5
# Remaining available resources: 468
# Step 18
# Agent 9 traded 1 resource with Agent 3! Payoff: 5.0
# Agent 4 acquired a resource! Total resources: 5, Payoff: 4.0
# Agent 8 traded 1 resource with Agent 1! Payoff: 2.5
# Agent 2 traded 1 resource with Agent 6! Payoff: 5.0
# Agent 1 acquired a resource! Total resources: 5, Payoff: 5.5
# Agent 5 traded 1 resource with Agent 2! Payoff: 5.5
# Agent 3 traded 1 resource with Agent 8! Payoff: 1.5
# Agent 0 traded 1 resource with Agent 5! Payoff: 6.0
# Agent 7 acquired a resource! Total resources: 4, Payoff: 3.5
# Remaining available resources: 465
# Step 19
# Agent 0 traded 1 resource with Agent 7! Payoff: 5.5
# Agent 5 traded 1 resource with Agent 0! Payoff: 6.0
# Agent 8 acquired a resource! Total resources: 5, Payoff: 4.5
# Agent 2 acquired a resource! Total resources: 5, Payoff: 7.0
# Agent 6 traded 1 resource with Agent 9! Payoff: 1.5
# Agent 3 traded 1 resource with Agent 5! Payoff: 1.0
# Agent 3 missed an opportunity! Payoff: 0.5
# Agent 9 traded 1 resource with Agent 3! Payoff: 5.5
# Remaining available resources: 463
# Step 20
# Agent 9 traded 1 resource with Agent 7! Payoff: 5.0
# Agent 3 acquired a resource! Total resources: 3, Payoff: 2.5
# Agent 1 traded 1 resource with Agent 7! Payoff: 5.0
# Agent 5 traded 1 resource with Agent 0! Payoff: 6.5
# Agent 4 traded 1 resource with Agent 5! Payoff: 3.5
# Agent 6 traded 1 resource with Agent 1! Payoff: 1.0
# Agent 6 missed an opportunity! Payoff: 0.5
# Agent 7 traded 1 resource with Agent 9! Payoff: 6.0
# Agent 0 traded 1 resource with Agent 5! Payoff: 7.0
# Remaining available resources: 462
# Step 21
# Agent 9 acquired a resource! Total resources: 6, Payoff: 7.0
# Agent 0 traded 1 resource with Agent 2! Payoff: 6.5
# Agent 8 traded 1 resource with Agent 6! Payoff: 4.0
# Agent 1 acquired a resource! Total resources: 6, Payoff: 7.0
# Agent 5 traded 1 resource with Agent 3! Payoff: 8.0
# Agent 2 traded 1 resource with Agent 7! Payoff: 7.5
# Agent 4 traded 1 resource with Agent 7! Payoff: 3.0
# Agent 6 traded 1 resource with Agent 9! Payoff: 1.0
# Agent 6 missed an opportunity! Payoff: 0.5
# Remaining available resources: 460
# Step 22
# Agent 2 traded 1 resource with Agent 9! Payoff: 7.0
# Agent 4 traded 1 resource with Agent 6! Payoff: 2.5
# Agent 5 acquired a resource! Total resources: 7, Payoff: 9.0
# Agent 7 traded 1 resource with Agent 0! Payoff: 7.5
# Agent 0 traded 1 resource with Agent 2! Payoff: 7.0
# Agent 3 traded 1 resource with Agent 6! Payoff: 3.0
# Agent 8 acquired a resource! Total resources: 5, Payoff: 5.0
# Agent 6 acquired a resource! Total resources: 4, Payoff: 3.5
# Remaining available resources: 457
# Step 23
# Agent 0 acquired a resource! Total resources: 7, Payoff: 8.0
# Agent 7 traded 1 resource with Agent 5! Payoff: 7.0
# Agent 4 traded 1 resource with Agent 0! Payoff: 2.0
# Agent 4 missed an opportunity! Payoff: 1.5
# Agent 3 traded 1 resource with Agent 5! Payoff: 2.5
# Agent 2 traded 1 resource with Agent 5! Payoff: 7.5
# Agent 1 traded 1 resource with Agent 8! Payoff: 6.5
# Remaining available resources: 456
# Step 24
# Agent 7 traded 1 resource with Agent 0! Payoff: 6.5
# Agent 1 traded 1 resource with Agent 7! Payoff: 6.0
# Agent 6 traded 1 resource with Agent 7! Payoff: 3.0
# Agent 5 acquired a resource! Total resources: 11, Payoff: 13.0
# Agent 8 traded 1 resource with Agent 6! Payoff: 5.5
# Agent 4 missed an opportunity! Payoff: 1.0
# Agent 9 acquired a resource! Total resources: 9, Payoff: 10.0
# Agent 3 traded 1 resource with Agent 7! Payoff: 2.0
# Agent 3 missed an opportunity! Payoff: 1.5
# Remaining available resources: 454
# Step 25
# Agent 1 traded 1 resource with Agent 6! Payoff: 5.5
# Agent 4 acquired a resource! Total resources: 2, Payoff: 2.0
# Agent 3 missed an opportunity! Payoff: 1.0
# Agent 8 traded 1 resource with Agent 2! Payoff: 5.0
# Agent 2 acquired a resource! Total resources: 6, Payoff: 9.5
# Agent 0 traded 1 resource with Agent 7! Payoff: 9.5
# Agent 7 acquired a resource! Total resources: 10, Payoff: 11.5
# Agent 6 traded 1 resource with Agent 5! Payoff: 4.5
# Remaining available resources: 451
# Step 26
# Agent 5 traded 1 resource with Agent 1! Payoff: 13.5
# Agent 7 acquired a resource! Total resources: 11, Payoff: 12.5
# Agent 0 traded 1 resource with Agent 7! Payoff: 9.0
# Agent 1 acquired a resource! Total resources: 5, Payoff: 7.5
# Agent 9 traded 1 resource with Agent 1! Payoff: 9.5
# Agent 8 acquired a resource! Total resources: 5, Payoff: 6.0
# Agent 6 traded 1 resource with Agent 7! Payoff: 4.0
# Agent 3 acquired a resource! Total resources: 2, Payoff: 2.0
# Remaining available resources: 447
# Step 27
# Agent 2 traded 1 resource with Agent 4! Payoff: 9.0
# Agent 4 traded 1 resource with Agent 7! Payoff: 2.5
# Agent 6 traded 1 resource with Agent 7! Payoff: 3.5
# Agent 0 traded 1 resource with Agent 7! Payoff: 8.5
# Agent 9 traded 1 resource with Agent 8! Payoff: 9.0
# Remaining available resources: 447
# Step 28
# Agent 0 traded 1 resource with Agent 1! Payoff: 8.0
# Agent 9 traded 1 resource with Agent 4! Payoff: 8.5
# Agent 2 acquired a resource! Total resources: 6, Payoff: 10.0
# Agent 5 traded 1 resource with Agent 9! Payoff: 13.0
# Agent 3 traded 1 resource with Agent 2! Payoff: 1.5
# Agent 3 missed an opportunity! Payoff: 1.0
# Agent 6 acquired a resource! Total resources: 3, Payoff: 4.5
# Agent 8 traded 1 resource with Agent 5! Payoff: 6.5
# Agent 7 traded 1 resource with Agent 3! Payoff: 17.0
# Agent 1 traded 1 resource with Agent 6! Payoff: 9.0
# Remaining available resources: 445
# Step 29
# Agent 0 traded 1 resource with Agent 5! Payoff: 7.5
# Agent 7 acquired a resource! Total resources: 16, Payoff: 18.0
# Agent 9 traded 1 resource with Agent 4! Payoff: 9.0
# Agent 8 traded 1 resource with Agent 0! Payoff: 6.0
# Agent 5 traded 1 resource with Agent 3! Payoff: 14.5
# Agent 4 traded 1 resource with Agent 3! Payoff: 4.0
# Agent 1 traded 1 resource with Agent 5! Payoff: 8.5
# Agent 3 traded 1 resource with Agent 0! Payoff: 3.5
# Remaining available resources: 444
# Step 30
# Agent 0 traded 1 resource with Agent 7! Payoff: 9.0
# Agent 8 traded 1 resource with Agent 6! Payoff: 5.5
# Agent 6 traded 1 resource with Agent 2! Payoff: 6.0
# Agent 1 acquired a resource! Total resources: 6, Payoff: 9.5
# Agent 2 traded 1 resource with Agent 4! Payoff: 11.5
# Agent 9 traded 1 resource with Agent 7! Payoff: 8.5
# Agent 4 traded 1 resource with Agent 5! Payoff: 4.5
# Agent 3 traded 1 resource with Agent 0! Payoff: 3.0
# Agent 5 traded 1 resource with Agent 0! Payoff: 16.0
# Remaining available resources: 443
# Step 31
# Agent 8 acquired a resource! Total resources: 4, Payoff: 6.5
# Agent 5 acquired a resource! Total resources: 13, Payoff: 17.0
# Agent 7 acquired a resource! Total resources: 19, Payoff: 21.0
# Agent 9 traded 1 resource with Agent 3! Payoff: 8.0
# Agent 4 traded 1 resource with Agent 8! Payoff: 4.0
# Agent 6 acquired a resource! Total resources: 5, Payoff: 7.0
# Agent 0 acquired a resource! Total resources: 8, Payoff: 12.0
# Agent 2 traded 1 resource with Agent 7! Payoff: 11.0
# Agent 3 traded 1 resource with Agent 7! Payoff: 3.5
# Remaining available resources: 438
# Step 32
# Agent 9 acquired a resource! Total resources: 5, Payoff: 9.0
# Agent 1 traded 1 resource with Agent 2! Payoff: 9.0
# Agent 2 traded 1 resource with Agent 1! Payoff: 11.5
# Agent 4 traded 1 resource with Agent 7! Payoff: 3.5
# Agent 4 missed an opportunity! Payoff: 3.0
# Remaining available resources: 437
# Step 33
# Agent 2 traded 1 resource with Agent 6! Payoff: 11.0
# Agent 3 traded 1 resource with Agent 9! Payoff: 3.0
# Agent 3 missed an opportunity! Payoff: 2.5
# Agent 4 acquired a resource! Total resources: 2, Payoff: 4.0
# Agent 6 traded 1 resource with Agent 0! Payoff: 7.5
# Agent 5 acquired a resource! Total resources: 14, Payoff: 18.0
# Agent 7 acquired a resource! Total resources: 23, Payoff: 25.0
# Agent 1 traded 1 resource with Agent 0! Payoff: 9.5
# Remaining available resources: 434
# Step 34
# Agent 6 traded 1 resource with Agent 9! Payoff: 7.0
# Agent 9 traded 1 resource with Agent 0! Payoff: 10.5
# Agent 8 traded 1 resource with Agent 0! Payoff: 7.0
# Agent 2 acquired a resource! Total resources: 6, Payoff: 12.0
# Agent 3 missed an opportunity! Payoff: 2.0
# Agent 0 acquired a resource! Total resources: 13, Payoff: 17.0
# Remaining available resources: 432
# Step 35
# Agent 7 traded 1 resource with Agent 1! Payoff: 24.5
# Agent 3 missed an opportunity! Payoff: 1.5
# Agent 6 acquired a resource! Total resources: 5, Payoff: 8.0
# Agent 5 acquired a resource! Total resources: 15, Payoff: 19.0
# Agent 1 traded 1 resource with Agent 6! Payoff: 10.0
# Agent 8 acquired a resource! Total resources: 5, Payoff: 8.0
# Agent 9 acquired a resource! Total resources: 7, Payoff: 11.5
# Agent 4 acquired a resource! Total resources: 3, Payoff: 5.0
# Remaining available resources: 427
# Step 36
# Agent 7 traded 1 resource with Agent 2! Payoff: 24.0
# Agent 0 traded 1 resource with Agent 7! Payoff: 16.5
# Agent 1 traded 1 resource with Agent 0! Payoff: 9.5
# Agent 2 acquired a resource! Total resources: 8, Payoff: 14.0
# Agent 3 acquired a resource! Total resources: 2, Payoff: 2.5
# Remaining available resources: 425
# Step 37
# Agent 7 traded 1 resource with Agent 3! Payoff: 24.5
# Agent 6 traded 1 resource with Agent 9! Payoff: 8.5
# Agent 8 traded 1 resource with Agent 2! Payoff: 7.5
# Agent 5 traded 1 resource with Agent 9! Payoff: 18.5
# Agent 4 traded 1 resource with Agent 1! Payoff: 4.5
# Agent 9 traded 1 resource with Agent 0! Payoff: 13.0
# Agent 1 traded 1 resource with Agent 6! Payoff: 10.0
# Agent 0 traded 1 resource with Agent 6! Payoff: 18.0
# Remaining available resources: 425
# Step 38
# Agent 5 traded 1 resource with Agent 8! Payoff: 18.0
# Agent 1 acquired a resource! Total resources: 5, Payoff: 11.0
# Agent 4 acquired a resource! Total resources: 3, Payoff: 5.5
# Agent 3 traded 1 resource with Agent 0! Payoff: 3.0
# Agent 0 traded 1 resource with Agent 7! Payoff: 18.5
# Agent 2 acquired a resource! Total resources: 10, Payoff: 16.0
# Agent 6 traded 1 resource with Agent 7! Payoff: 10.0
# Agent 8 traded 1 resource with Agent 7! Payoff: 8.0
# Agent 9 traded 1 resource with Agent 6! Payoff: 12.5
# Agent 7 acquired a resource! Total resources: 25, Payoff: 28.5
# Remaining available resources: 421
# Step 39
# Agent 3 acquired a resource! Total resources: 3, Payoff: 4.0
# Agent 0 traded 1 resource with Agent 1! Payoff: 18.0
# Agent 6 traded 1 resource with Agent 7! Payoff: 10.5
# Agent 8 traded 1 resource with Agent 3! Payoff: 7.5
# Agent 5 traded 1 resource with Agent 1! Payoff: 17.5
# Remaining available resources: 420
# Step 40
# Agent 4 acquired a resource! Total resources: 4, Payoff: 6.5
# Agent 0 acquired a resource! Total resources: 13, Payoff: 19.0
# Agent 1 traded 1 resource with Agent 3! Payoff: 12.5
# Agent 2 traded 1 resource with Agent 8! Payoff: 15.5
# Agent 5 acquired a resource! Total resources: 13, Payoff: 18.5
# Agent 7 traded 1 resource with Agent 0! Payoff: 29.0
# Agent 8 traded 1 resource with Agent 1! Payoff: 8.0
# Agent 9 acquired a resource! Total resources: 8, Payoff: 13.5
# Agent 6 traded 1 resource with Agent 2! Payoff: 10.0
# Remaining available resources: 416
# Step 41
# Agent 1 traded 1 resource with Agent 7! Payoff: 13.0
# Agent 7 acquired a resource! Total resources: 27, Payoff: 31.0
# Agent 6 traded 1 resource with Agent 7! Payoff: 9.5
# Agent 8 acquired a resource! Total resources: 4, Payoff: 9.0
# Agent 2 acquired a resource! Total resources: 11, Payoff: 17.5
# Agent 3 traded 1 resource with Agent 8! Payoff: 5.5
# Remaining available resources: 413
# Step 42
# Agent 4 traded 1 resource with Agent 0! Payoff: 6.0
# Agent 1 traded 1 resource with Agent 6! Payoff: 12.5
# Agent 5 acquired a resource! Total resources: 14, Payoff: 19.5
# Agent 0 traded 1 resource with Agent 8! Payoff: 20.5
# Agent 6 acquired a resource! Total resources: 6, Payoff: 11.5
# Agent 3 traded 1 resource with Agent 5! Payoff: 5.0
# Agent 9 traded 1 resource with Agent 3! Payoff: 13.0
# Remaining available resources: 411
# Step 43
# Agent 3 traded 1 resource with Agent 4! Payoff: 5.5
# Agent 9 traded 1 resource with Agent 2! Payoff: 12.5
# Agent 7 acquired a resource! Total resources: 29, Payoff: 33.0
# Agent 4 acquired a resource! Total resources: 5, Payoff: 8.0
# Agent 0 traded 1 resource with Agent 6! Payoff: 20.0
# Agent 1 traded 1 resource with Agent 5! Payoff: 12.0
# Agent 8 traded 1 resource with Agent 3! Payoff: 10.5
# Remaining available resources: 409
# Step 44
# Agent 6 traded 1 resource with Agent 5! Payoff: 12.0
# Agent 2 traded 1 resource with Agent 8! Payoff: 18.0
# Agent 9 traded 1 resource with Agent 0! Payoff: 12.0
# Agent 8 traded 1 resource with Agent 2! Payoff: 11.0
# Agent 0 acquired a resource! Total resources: 15, Payoff: 22.0
# Agent 1 traded 1 resource with Agent 4! Payoff: 11.5
# Agent 5 traded 1 resource with Agent 6! Payoff: 22.0
# Agent 3 traded 1 resource with Agent 0! Payoff: 6.0
# Remaining available resources: 408
# Step 45
# Agent 4 traded 1 resource with Agent 5! Payoff: 8.5
# Agent 9 traded 1 resource with Agent 0! Payoff: 11.5
# Agent 8 acquired a resource! Total resources: 6, Payoff: 12.0
# Agent 7 traded 1 resource with Agent 4! Payoff: 32.5
# Agent 5 traded 1 resource with Agent 1! Payoff: 22.5
# Agent 3 traded 1 resource with Agent 7! Payoff: 5.5
# Agent 6 traded 1 resource with Agent 4! Payoff: 12.5
# Agent 2 traded 1 resource with Agent 6! Payoff: 18.5
# Agent 1 traded 1 resource with Agent 5! Payoff: 12.0
# Remaining available resources: 407
# Step 46
# Agent 3 acquired a resource! Total resources: 3, Payoff: 6.5
# Agent 2 traded 1 resource with Agent 1! Payoff: 18.0
# Agent 6 traded 1 resource with Agent 7! Payoff: 13.0
# Agent 9 traded 1 resource with Agent 6! Payoff: 11.0
# Agent 1 acquired a resource! Total resources: 5, Payoff: 14.0
# Agent 0 traded 1 resource with Agent 5! Payoff: 23.5
# Agent 7 traded 1 resource with Agent 2! Payoff: 34.0
# Agent 5 traded 1 resource with Agent 1! Payoff: 24.0
# Remaining available resources: 405
# Step 47
# Agent 2 acquired a resource! Total resources: 12, Payoff: 20.0
# Agent 6 traded 1 resource with Agent 0! Payoff: 13.5
# Agent 0 traded 1 resource with Agent 3! Payoff: 24.0
# Agent 9 acquired a resource! Total resources: 4, Payoff: 12.0
# Agent 7 acquired a resource! Total resources: 30, Payoff: 35.0
# Agent 4 traded 1 resource with Agent 6! Payoff: 10.0
# Agent 8 traded 1 resource with Agent 4! Payoff: 11.5
# Agent 5 traded 1 resource with Agent 1! Payoff: 23.5
# Remaining available resources: 402
# Step 48
# Agent 4 traded 1 resource with Agent 1! Payoff: 10.5
# Agent 1 traded 1 resource with Agent 5! Payoff: 16.5
# Agent 6 traded 1 resource with Agent 0! Payoff: 14.0
# Agent 0 acquired a resource! Total resources: 18, Payoff: 26.0
# Agent 5 traded 1 resource with Agent 9! Payoff: 24.0
# Agent 8 traded 1 resource with Agent 5! Payoff: 11.0
# Agent 3 traded 1 resource with Agent 9! Payoff: 7.0
# Remaining available resources: 401
# Step 49
# Agent 1 traded 1 resource with Agent 7! Payoff: 16.0
# Agent 2 traded 1 resource with Agent 0! Payoff: 19.5
# Agent 6 acquired a resource! Total resources: 7, Payoff: 15.0
# Agent 8 traded 1 resource with Agent 7! Payoff: 10.5
# Agent 9 traded 1 resource with Agent 7! Payoff: 13.5
# Agent 5 traded 1 resource with Agent 0! Payoff: 24.5
# Agent 7 traded 1 resource with Agent 5! Payoff: 37.5
# Agent 3 traded 1 resource with Agent 0! Payoff: 6.5
# Agent 4 acquired a resource! Total resources: 7, Payoff: 11.5
# Remaining available resources: 399
# Step 50
# Agent 8 traded 1 resource with Agent 6! Payoff: 10.0
# Agent 9 traded 1 resource with Agent 5! Payoff: 13.0
# Agent 2 traded 1 resource with Agent 3! Payoff: 19.0
# Agent 0 traded 1 resource with Agent 3! Payoff: 28.5
# Agent 3 traded 1 resource with Agent 6! Payoff: 8.0
# Agent 7 acquired a resource! Total resources: 33, Payoff: 38.5
# Agent 5 acquired a resource! Total resources: 19, Payoff: 27.5
# Agent 1 traded 1 resource with Agent 0! Payoff: 15.5
# Remaining available resources: 397
# Step 51
# Agent 4 traded 1 resource with Agent 3! Payoff: 11.0
# Agent 0 traded 1 resource with Agent 1! Payoff: 29.0
# Agent 2 traded 1 resource with Agent 8! Payoff: 18.5
# Agent 9 acquired a resource! Total resources: 5, Payoff: 14.0
# Agent 1 acquired a resource! Total resources: 7, Payoff: 17.5
# Agent 6 traded 1 resource with Agent 8! Payoff: 16.5
# Agent 3 traded 1 resource with Agent 6! Payoff: 8.5
# Agent 8 traded 1 resource with Agent 3! Payoff: 11.5
# Remaining available resources: 395
# Step 52
# Agent 8 acquired a resource! Total resources: 4, Payoff: 12.5
# Agent 5 traded 1 resource with Agent 1! Payoff: 27.0
# Agent 7 acquired a resource! Total resources: 34, Payoff: 39.5
# Agent 0 traded 1 resource with Agent 5! Payoff: 28.5
# Agent 3 traded 1 resource with Agent 8! Payoff: 9.0
# Agent 4 traded 1 resource with Agent 1! Payoff: 10.5
# Remaining available resources: 393
# Step 53
# Agent 4 traded 1 resource with Agent 3! Payoff: 10.0
# Agent 5 traded 1 resource with Agent 2! Payoff: 27.5
# Agent 1 traded 1 resource with Agent 4! Payoff: 19.0
# Agent 2 traded 1 resource with Agent 9! Payoff: 19.0
# Agent 0 acquired a resource! Total resources: 20, Payoff: 29.5
# Agent 6 traded 1 resource with Agent 9! Payoff: 17.0
# Agent 3 acquired a resource! Total resources: 5, Payoff: 11.0
# Remaining available resources: 391
# Step 54
# Agent 1 traded 1 resource with Agent 5! Payoff: 18.5
# Agent 6 traded 1 resource with Agent 9! Payoff: 16.5
# Agent 5 traded 1 resource with Agent 9! Payoff: 28.0
# Agent 2 traded 1 resource with Agent 0! Payoff: 18.5
# Agent 8 traded 1 resource with Agent 2! Payoff: 13.0
# Agent 9 acquired a resource! Total resources: 10, Payoff: 19.0
# Agent 7 traded 1 resource with Agent 5! Payoff: 39.0
# Agent 4 traded 1 resource with Agent 5! Payoff: 10.5
# Remaining available resources: 390
# Step 55
# Agent 5 acquired a resource! Total resources: 21, Payoff: 31.0
# Agent 8 traded 1 resource with Agent 5! Payoff: 12.5
# Agent 3 traded 1 resource with Agent 4! Payoff: 10.5
# Agent 0 traded 1 resource with Agent 6! Payoff: 30.0
# Agent 4 acquired a resource! Total resources: 6, Payoff: 12.5
# Agent 6 traded 1 resource with Agent 5! Payoff: 17.0
# Agent 7 traded 1 resource with Agent 4! Payoff: 38.5
# Agent 1 acquired a resource! Total resources: 8, Payoff: 19.5
# Agent 2 acquired a resource! Total resources: 10, Payoff: 20.5
# Remaining available resources: 386
# Step 56
# Agent 6 acquired a resource! Total resources: 8, Payoff: 18.0
# Agent 9 traded 1 resource with Agent 5! Payoff: 18.5
# Agent 0 acquired a resource! Total resources: 21, Payoff: 31.0
# Agent 8 traded 1 resource with Agent 9! Payoff: 12.0
# Agent 7 traded 1 resource with Agent 4! Payoff: 38.0
# Agent 3 traded 1 resource with Agent 6! Payoff: 10.0
# Remaining available resources: 384
# Step 57
# Agent 8 traded 1 resource with Agent 2! Payoff: 11.5
# Agent 8 missed an opportunity! Payoff: 11.0
# Agent 7 traded 1 resource with Agent 9! Payoff: 37.5
# Agent 4 traded 1 resource with Agent 3! Payoff: 14.0
# Agent 9 traded 1 resource with Agent 7! Payoff: 20.0
# Agent 3 traded 1 resource with Agent 7! Payoff: 10.5
# Agent 2 traded 1 resource with Agent 4! Payoff: 21.0
# Remaining available resources: 384
# Step 58
# Agent 9 traded 1 resource with Agent 8! Payoff: 19.5
# Agent 4 traded 1 resource with Agent 7! Payoff: 14.5
# Agent 3 acquired a resource! Total resources: 4, Payoff: 11.5
# Agent 5 traded 1 resource with Agent 1! Payoff: 33.5
# Agent 0 traded 1 resource with Agent 1! Payoff: 30.5
# Agent 7 acquired a resource! Total resources: 34, Payoff: 41.5
# Agent 1 traded 1 resource with Agent 7! Payoff: 21.0
# Agent 2 traded 1 resource with Agent 5! Payoff: 20.5
# Agent 6 traded 1 resource with Agent 2! Payoff: 18.5
# Agent 8 acquired a resource! Total resources: 3, Payoff: 13.0
# Remaining available resources: 381
# Step 59
# Agent 2 traded 1 resource with Agent 9! Payoff: 21.0
# Agent 9 traded 1 resource with Agent 3! Payoff: 20.0
# Agent 1 traded 1 resource with Agent 3! Payoff: 20.5
# Agent 5 traded 1 resource with Agent 2! Payoff: 34.0
# Agent 0 traded 1 resource with Agent 4! Payoff: 30.0
# Agent 4 traded 1 resource with Agent 5! Payoff: 15.0
# Agent 6 traded 1 resource with Agent 1! Payoff: 18.0
# Remaining available resources: 381
# Step 60
# Agent 4 traded 1 resource with Agent 7! Payoff: 14.5
# Agent 5 acquired a resource! Total resources: 25, Payoff: 36.0
# Agent 8 traded 1 resource with Agent 6! Payoff: 12.5
# Agent 0 traded 1 resource with Agent 8! Payoff: 29.5
# Agent 6 traded 1 resource with Agent 8! Payoff: 18.5
# Agent 1 traded 1 resource with Agent 7! Payoff: 21.0
# Agent 2 acquired a resource! Total resources: 11, Payoff: 23.0
# Agent 3 traded 1 resource with Agent 1! Payoff: 13.0
# Agent 9 traded 1 resource with Agent 4! Payoff: 19.5
# Remaining available resources: 379
# Step 61
# Agent 8 traded 1 resource with Agent 9! Payoff: 14.0
# Agent 7 acquired a resource! Total resources: 38, Payoff: 45.5
# Agent 0 traded 1 resource with Agent 6! Payoff: 29.0
# Agent 6 traded 1 resource with Agent 4! Payoff: 19.0
# Agent 9 traded 1 resource with Agent 2! Payoff: 20.0
# Agent 4 traded 1 resource with Agent 9! Payoff: 16.0
# Agent 1 traded 1 resource with Agent 3! Payoff: 21.5
# Agent 3 acquired a resource! Total resources: 7, Payoff: 15.0
# Remaining available resources: 377
# Step 62
# Agent 1 traded 1 resource with Agent 7! Payoff: 21.0
# Agent 4 traded 1 resource with Agent 6! Payoff: 15.5
# Agent 0 traded 1 resource with Agent 9! Payoff: 28.5
# Agent 5 traded 1 resource with Agent 3! Payoff: 35.5
# Agent 9 acquired a resource! Total resources: 11, Payoff: 23.0
# Agent 6 traded 1 resource with Agent 2! Payoff: 19.5
# Agent 8 traded 1 resource with Agent 9! Payoff: 13.5
# Agent 2 traded 1 resource with Agent 1! Payoff: 24.5
# Remaining available resources: 376
# Step 63
# Agent 6 traded 1 resource with Agent 3! Payoff: 19.0
# Agent 4 acquired a resource! Total resources: 7, Payoff: 16.5
# Agent 5 traded 1 resource with Agent 9! Payoff: 35.0
# Agent 2 traded 1 resource with Agent 4! Payoff: 24.0
# Agent 1 traded 1 resource with Agent 6! Payoff: 21.5
# Agent 8 traded 1 resource with Agent 1! Payoff: 13.0
# Agent 8 missed an opportunity! Payoff: 12.5
# Agent 3 traded 1 resource with Agent 8! Payoff: 16.5
# Agent 7 acquired a resource! Total resources: 40, Payoff: 47.5
# Remaining available resources: 374
# Step 64
# Agent 6 traded 1 resource with Agent 5! Payoff: 19.5
# Agent 1 traded 1 resource with Agent 2! Payoff: 22.0
# Agent 9 traded 1 resource with Agent 7! Payoff: 24.5
# Agent 3 traded 1 resource with Agent 9! Payoff: 16.0
# Agent 5 acquired a resource! Total resources: 25, Payoff: 37.0
# Agent 7 acquired a resource! Total resources: 42, Payoff: 49.5
# Agent 8 acquired a resource! Total resources: 3, Payoff: 14.5
# Agent 0 traded 1 resource with Agent 7! Payoff: 28.0
# Agent 2 traded 1 resource with Agent 7! Payoff: 24.5
# Remaining available resources: 371
# Step 65
# Agent 4 traded 1 resource with Agent 1! Payoff: 17.0
# Agent 3 acquired a resource! Total resources: 8, Payoff: 17.0
# Agent 1 acquired a resource! Total resources: 9, Payoff: 24.0
# Agent 6 traded 1 resource with Agent 3! Payoff: 19.0
# Agent 2 acquired a resource! Total resources: 12, Payoff: 25.5
# Agent 0 traded 1 resource with Agent 7! Payoff: 27.5
# Agent 9 traded 1 resource with Agent 7! Payoff: 25.0
# Remaining available resources: 368
# Step 66
# Agent 4 traded 1 resource with Agent 0! Payoff: 16.5
# Agent 8 traded 1 resource with Agent 1! Payoff: 14.0
# Agent 0 acquired a resource! Total resources: 16, Payoff: 29.5
# Agent 6 acquired a resource! Total resources: 6, Payoff: 20.0
# Agent 7 traded 1 resource with Agent 0! Payoff: 53.0
# Agent 9 acquired a resource! Total resources: 13, Payoff: 26.0
# Agent 5 acquired a resource! Total resources: 26, Payoff: 38.0
# Remaining available resources: 364
# Step 67
# Agent 3 traded 1 resource with Agent 9! Payoff: 17.5
# Agent 7 traded 1 resource with Agent 1! Payoff: 52.5
# Agent 8 traded 1 resource with Agent 0! Payoff: 13.5
# Agent 8 missed an opportunity! Payoff: 13.0
# Agent 4 traded 1 resource with Agent 1! Payoff: 16.0
# Agent 2 traded 1 resource with Agent 0! Payoff: 25.0
# Agent 1 traded 1 resource with Agent 4! Payoff: 26.5
# Remaining available resources: 364
# Step 68
# Agent 3 traded 1 resource with Agent 8! Payoff: 17.0
# Agent 8 acquired a resource! Total resources: 3, Payoff: 15.0
# Agent 6 acquired a resource! Total resources: 7, Payoff: 21.0
# Agent 7 traded 1 resource with Agent 4! Payoff: 52.0
# Agent 5 traded 1 resource with Agent 4! Payoff: 37.5
# Agent 0 traded 1 resource with Agent 7! Payoff: 32.0
# Agent 9 traded 1 resource with Agent 4! Payoff: 26.5
# Agent 4 traded 1 resource with Agent 5! Payoff: 19.5
# Agent 1 traded 1 resource with Agent 3! Payoff: 26.0
# Agent 2 traded 1 resource with Agent 6! Payoff: 24.5
# Remaining available resources: 362
# Step 69
# Agent 4 acquired a resource! Total resources: 9, Payoff: 20.5
# Agent 0 traded 1 resource with Agent 9! Payoff: 31.5
# Agent 9 traded 1 resource with Agent 8! Payoff: 27.0
# Agent 5 traded 1 resource with Agent 3! Payoff: 38.0
# Agent 7 traded 1 resource with Agent 1! Payoff: 52.5
# Agent 1 acquired a resource! Total resources: 12, Payoff: 28.0
# Agent 3 traded 1 resource with Agent 9! Payoff: 18.5
# Agent 2 acquired a resource! Total resources: 11, Payoff: 25.5
# Remaining available resources: 359
# Step 70
# Agent 5 traded 1 resource with Agent 7! Payoff: 37.5
# Agent 7 acquired a resource! Total resources: 45, Payoff: 54.5
# Agent 0 traded 1 resource with Agent 8! Payoff: 31.0
# Agent 8 traded 1 resource with Agent 2! Payoff: 16.5
# Agent 3 traded 1 resource with Agent 6! Payoff: 18.0
# Agent 6 traded 1 resource with Agent 9! Payoff: 22.5
# Agent 9 acquired a resource! Total resources: 16, Payoff: 30.0
# Remaining available resources: 357
# Step 71
# Agent 4 traded 1 resource with Agent 2! Payoff: 20.0
# Agent 3 acquired a resource! Total resources: 8, Payoff: 19.0
# Agent 1 traded 1 resource with Agent 7! Payoff: 27.5
# Agent 5 traded 1 resource with Agent 8! Payoff: 37.0
# Agent 2 traded 1 resource with Agent 0! Payoff: 27.0
# Agent 0 traded 1 resource with Agent 2! Payoff: 31.5
# Agent 8 traded 1 resource with Agent 2! Payoff: 17.0
# Remaining available resources: 356
# Step 72
# Agent 5 acquired a resource! Total resources: 24, Payoff: 38.0
# Agent 8 traded 1 resource with Agent 9! Payoff: 16.5
# Agent 4 traded 1 resource with Agent 3! Payoff: 19.5
# Agent 7 traded 1 resource with Agent 8! Payoff: 55.0
# Agent 9 traded 1 resource with Agent 1! Payoff: 30.5
# Agent 0 acquired a resource! Total resources: 17, Payoff: 32.5
# Agent 6 traded 1 resource with Agent 0! Payoff: 22.0
# Agent 2 traded 1 resource with Agent 1! Payoff: 28.5
# Agent 1 traded 1 resource with Agent 6! Payoff: 29.0
# Remaining available resources: 354
# Step 73
# Agent 6 traded 1 resource with Agent 1! Payoff: 22.5
# Agent 9 traded 1 resource with Agent 4! Payoff: 30.0
# Agent 3 traded 1 resource with Agent 1! Payoff: 19.5
# Agent 8 acquired a resource! Total resources: 5, Payoff: 18.5
# Agent 7 traded 1 resource with Agent 6! Payoff: 54.5
# Agent 2 traded 1 resource with Agent 1! Payoff: 28.0
# Remaining available resources: 353
# Step 74
# Agent 2 traded 1 resource with Agent 0! Payoff: 27.5
# Agent 9 traded 1 resource with Agent 5! Payoff: 29.5
# Agent 4 traded 1 resource with Agent 8! Payoff: 20.0
# Agent 5 traded 1 resource with Agent 2! Payoff: 38.5
# Agent 0 traded 1 resource with Agent 9! Payoff: 34.0
# Agent 7 traded 1 resource with Agent 6! Payoff: 54.0
# Agent 3 traded 1 resource with Agent 8! Payoff: 19.0
# Agent 6 traded 1 resource with Agent 0! Payoff: 24.0
# Agent 1 traded 1 resource with Agent 3! Payoff: 31.5
# Remaining available resources: 353
# Step 75
# Agent 5 traded 1 resource with Agent 1! Payoff: 38.0
# Agent 3 traded 1 resource with Agent 2! Payoff: 19.5
# Agent 1 acquired a resource! Total resources: 16, Payoff: 33.5
# Agent 4 traded 1 resource with Agent 6! Payoff: 19.5
# Agent 6 acquired a resource! Total resources: 10, Payoff: 26.0
# Agent 0 acquired a resource! Total resources: 20, Payoff: 36.0
# Agent 2 traded 1 resource with Agent 6! Payoff: 29.0
# Agent 8 traded 1 resource with Agent 5! Payoff: 20.0
# Agent 9 acquired a resource! Total resources: 16, Payoff: 31.5
# Agent 7 acquired a resource! Total resources: 44, Payoff: 55.0
# Remaining available resources: 348
# Step 76
# Agent 3 traded 1 resource with Agent 6! Payoff: 19.0
# Agent 2 traded 1 resource with Agent 6! Payoff: 28.5
# Agent 6 acquired a resource! Total resources: 14, Payoff: 30.0
# Agent 4 traded 1 resource with Agent 3! Payoff: 19.0
# Agent 8 traded 1 resource with Agent 0! Payoff: 19.5
# Remaining available resources: 347
# Step 77
# Agent 7 traded 1 resource with Agent 8! Payoff: 54.5
# Agent 3 traded 1 resource with Agent 8! Payoff: 19.5
# Agent 0 traded 1 resource with Agent 4! Payoff: 36.5
# Agent 5 acquired a resource! Total resources: 25, Payoff: 40.0
# Agent 4 acquired a resource! Total resources: 7, Payoff: 21.0
# Agent 9 traded 1 resource with Agent 0! Payoff: 31.0
# Agent 2 acquired a resource! Total resources: 12, Payoff: 29.5
# Agent 8 acquired a resource! Total resources: 8, Payoff: 22.5
# Agent 1 traded 1 resource with Agent 4! Payoff: 33.0
# Remaining available resources: 343
# Step 78
# Agent 0 traded 1 resource with Agent 1! Payoff: 37.0
# Agent 7 acquired a resource! Total resources: 44, Payoff: 55.5
# Agent 4 acquired a resource! Total resources: 9, Payoff: 23.0
# Agent 9 traded 1 resource with Agent 7! Payoff: 30.5
# Agent 6 traded 1 resource with Agent 4! Payoff: 29.5
# Agent 1 traded 1 resource with Agent 2! Payoff: 33.5
# Remaining available resources: 341
# Step 79
# Agent 6 traded 1 resource with Agent 5! Payoff: 29.0
# Agent 8 traded 1 resource with Agent 9! Payoff: 22.0
# Agent 2 acquired a resource! Total resources: 14, Payoff: 31.5
# Agent 1 traded 1 resource with Agent 7! Payoff: 33.0
# Agent 9 acquired a resource! Total resources: 16, Payoff: 32.5
# Agent 0 acquired a resource! Total resources: 21, Payoff: 38.0
# Remaining available resources: 338
# Step 80
# Agent 7 traded 1 resource with Agent 5! Payoff: 57.0
# Agent 3 traded 1 resource with Agent 6! Payoff: 19.0
# Agent 8 traded 1 resource with Agent 6! Payoff: 21.5
# Agent 4 traded 1 resource with Agent 0! Payoff: 23.5
# Agent 5 acquired a resource! Total resources: 28, Payoff: 43.0
# Agent 6 acquired a resource! Total resources: 15, Payoff: 32.0
# Agent 1 traded 1 resource with Agent 3! Payoff: 32.5
# Remaining available resources: 336
# Step 81
# Agent 9 traded 1 resource with Agent 7! Payoff: 32.0
# Agent 0 traded 1 resource with Agent 4! Payoff: 38.5
# Agent 1 traded 1 resource with Agent 9! Payoff: 32.0
# Agent 7 traded 1 resource with Agent 6! Payoff: 57.5
# Agent 3 acquired a resource! Total resources: 7, Payoff: 21.0
# Agent 2 traded 1 resource with Agent 5! Payoff: 31.0
# Agent 4 traded 1 resource with Agent 7! Payoff: 24.0
# Agent 8 traded 1 resource with Agent 3! Payoff: 21.0
# Remaining available resources: 335
# Step 82
# Agent 8 acquired a resource! Total resources: 6, Payoff: 22.0
# Agent 4 acquired a resource! Total resources: 10, Payoff: 25.0
# Agent 1 traded 1 resource with Agent 4! Payoff: 31.5
# Agent 6 traded 1 resource with Agent 5! Payoff: 32.5
# Agent 0 traded 1 resource with Agent 1! Payoff: 38.0
# Agent 9 acquired a resource! Total resources: 17, Payoff: 34.0
# Agent 7 traded 1 resource with Agent 8! Payoff: 58.0
# Agent 2 acquired a resource! Total resources: 14, Payoff: 32.0
# Agent 5 traded 1 resource with Agent 9! Payoff: 44.5
# Remaining available resources: 331
# Step 83
# Agent 0 acquired a resource! Total resources: 21, Payoff: 39.0
# Agent 1 traded 1 resource with Agent 0! Payoff: 32.0
# Agent 6 traded 1 resource with Agent 8! Payoff: 32.0
# Agent 3 acquired a resource! Total resources: 9, Payoff: 23.0
# Agent 7 acquired a resource! Total resources: 46, Payoff: 59.0
# Remaining available resources: 328
# Step 84
# Agent 2 traded 1 resource with Agent 9! Payoff: 31.5
# Agent 6 acquired a resource! Total resources: 15, Payoff: 33.0
# Agent 5 traded 1 resource with Agent 0! Payoff: 44.0
# Agent 4 traded 1 resource with Agent 0! Payoff: 25.5
# Agent 1 traded 1 resource with Agent 3! Payoff: 31.5
# Agent 9 traded 1 resource with Agent 8! Payoff: 35.5
# Agent 8 traded 1 resource with Agent 4! Payoff: 24.5
# Remaining available resources: 327
# Step 85
# Agent 9 acquired a resource! Total resources: 19, Payoff: 36.5
# Agent 1 acquired a resource! Total resources: 11, Payoff: 32.5
# Agent 5 acquired a resource! Total resources: 29, Payoff: 45.0
# Agent 2 traded 1 resource with Agent 6! Payoff: 31.0
# Agent 8 traded 1 resource with Agent 2! Payoff: 24.0
# Agent 3 traded 1 resource with Agent 9! Payoff: 23.5
# Agent 0 traded 1 resource with Agent 8! Payoff: 41.5
# Agent 4 traded 1 resource with Agent 3! Payoff: 26.0
# Agent 7 traded 1 resource with Agent 8! Payoff: 58.5
# Remaining available resources: 324
# Step 86
# Agent 6 traded 1 resource with Agent 0! Payoff: 33.5
# Agent 7 acquired a resource! Total resources: 46, Payoff: 59.5
# Agent 2 traded 1 resource with Agent 4! Payoff: 31.5
# Agent 3 traded 1 resource with Agent 9! Payoff: 24.0
# Agent 4 acquired a resource! Total resources: 12, Payoff: 28.0
# Agent 0 traded 1 resource with Agent 3! Payoff: 42.0
# Agent 8 traded 1 resource with Agent 7! Payoff: 25.5
# Remaining available resources: 322
# Step 87
# Agent 0 acquired a resource! Total resources: 24, Payoff: 43.0
# Agent 2 traded 1 resource with Agent 5! Payoff: 31.0
# Agent 6 traded 1 resource with Agent 2! Payoff: 33.0
# Agent 9 traded 1 resource with Agent 7! Payoff: 38.0
# Agent 3 acquired a resource! Total resources: 11, Payoff: 26.0
# Agent 5 traded 1 resource with Agent 1! Payoff: 45.5
# Agent 1 traded 1 resource with Agent 4! Payoff: 33.0
# Agent 8 traded 1 resource with Agent 9! Payoff: 25.0
# Remaining available resources: 320
# Step 88
# Agent 9 traded 1 resource with Agent 1! Payoff: 38.5
# Agent 8 acquired a resource! Total resources: 8, Payoff: 26.0
# Agent 2 traded 1 resource with Agent 6! Payoff: 31.5
# Agent 4 traded 1 resource with Agent 8! Payoff: 28.5
# Agent 1 traded 1 resource with Agent 4! Payoff: 33.5
# Agent 6 traded 1 resource with Agent 1! Payoff: 33.5
# Agent 7 traded 1 resource with Agent 8! Payoff: 61.0
# Remaining available resources: 319
# Step 89
# Agent 2 traded 1 resource with Agent 6! Payoff: 31.0
# Agent 5 traded 1 resource with Agent 8! Payoff: 45.0
# Agent 3 acquired a resource! Total resources: 12, Payoff: 27.0
# Agent 7 traded 1 resource with Agent 6! Payoff: 60.5
# Agent 1 acquired a resource! Total resources: 13, Payoff: 35.5
# Agent 0 traded 1 resource with Agent 3! Payoff: 42.5
# Agent 4 acquired a resource! Total resources: 14, Payoff: 30.5
# Agent 9 acquired a resource! Total resources: 21, Payoff: 39.5
# Remaining available resources: 315
# Step 90
# Agent 2 acquired a resource! Total resources: 11, Payoff: 32.0
# Agent 6 traded 1 resource with Agent 7! Payoff: 35.0
# Agent 8 traded 1 resource with Agent 2! Payoff: 28.5
# Agent 4 acquired a resource! Total resources: 15, Payoff: 31.5
# Agent 7 acquired a resource! Total resources: 48, Payoff: 62.5
# Agent 5 traded 1 resource with Agent 0! Payoff: 44.5
# Agent 0 traded 1 resource with Agent 2! Payoff: 43.0
# Remaining available resources: 312
# Step 91
# Agent 9 traded 1 resource with Agent 6! Payoff: 39.0
# Agent 1 traded 1 resource with Agent 5! Payoff: 35.0
# Agent 5 acquired a resource! Total resources: 29, Payoff: 46.5
# Agent 0 traded 1 resource with Agent 1! Payoff: 42.5
# Agent 6 traded 1 resource with Agent 9! Payoff: 35.5
# Agent 3 traded 1 resource with Agent 2! Payoff: 27.5
# Agent 8 traded 1 resource with Agent 9! Payoff: 28.0
# Remaining available resources: 311
# Step 92
# Agent 4 traded 1 resource with Agent 6! Payoff: 31.0
# Agent 0 traded 1 resource with Agent 6! Payoff: 42.0
# Agent 8 traded 1 resource with Agent 6! Payoff: 27.5
# Agent 6 acquired a resource! Total resources: 19, Payoff: 39.5
# Agent 3 traded 1 resource with Agent 0! Payoff: 27.0
# Agent 2 traded 1 resource with Agent 0! Payoff: 34.5
# Agent 1 traded 1 resource with Agent 8! Payoff: 35.5
# Agent 7 traded 1 resource with Agent 0! Payoff: 62.0
# Agent 9 traded 1 resource with Agent 2! Payoff: 40.5
# Remaining available resources: 310
# Step 93
# Agent 4 traded 1 resource with Agent 3! Payoff: 30.5
# Agent 1 traded 1 resource with Agent 9! Payoff: 35.0
# Agent 8 acquired a resource! Total resources: 10, Payoff: 29.5
# Agent 9 traded 1 resource with Agent 5! Payoff: 41.0
# Agent 2 traded 1 resource with Agent 0! Payoff: 35.0
# Agent 7 traded 1 resource with Agent 6! Payoff: 61.5
# Agent 5 acquired a resource! Total resources: 31, Payoff: 48.5
# Agent 0 acquired a resource! Total resources: 26, Payoff: 47.0
# Agent 3 acquired a resource! Total resources: 13, Payoff: 29.0
# Remaining available resources: 306
# Step 94
# Agent 9 traded 1 resource with Agent 8! Payoff: 40.5
# Agent 1 traded 1 resource with Agent 8! Payoff: 34.5
# Agent 7 acquired a resource! Total resources: 47, Payoff: 62.5
# Agent 4 traded 1 resource with Agent 8! Payoff: 30.0
# Agent 6 traded 1 resource with Agent 8! Payoff: 40.0
# Agent 2 acquired a resource! Total resources: 14, Payoff: 36.0
# Remaining available resources: 304
# Step 95
# Agent 5 acquired a resource! Total resources: 32, Payoff: 49.5
# Agent 8 traded 1 resource with Agent 5! Payoff: 33.0
# Agent 6 traded 1 resource with Agent 9! Payoff: 39.5
# Agent 1 acquired a resource! Total resources: 11, Payoff: 35.5
# Agent 0 acquired a resource! Total resources: 27, Payoff: 48.0
# Agent 4 traded 1 resource with Agent 0! Payoff: 29.5
# Agent 9 traded 1 resource with Agent 8! Payoff: 41.0
# Agent 3 traded 1 resource with Agent 7! Payoff: 28.5
# Remaining available resources: 301
# Step 96
# Agent 3 acquired a resource! Total resources: 13, Payoff: 29.5
# Agent 9 traded 1 resource with Agent 6! Payoff: 40.5
# Agent 4 acquired a resource! Total resources: 12, Payoff: 30.5
# Agent 8 traded 1 resource with Agent 0! Payoff: 33.5
# Agent 6 traded 1 resource with Agent 3! Payoff: 40.0
# Agent 7 traded 1 resource with Agent 6! Payoff: 63.0
# Remaining available resources: 299
# Step 97
# Agent 8 traded 1 resource with Agent 9! Payoff: 33.0
# Agent 6 acquired a resource! Total resources: 20, Payoff: 42.0
# Agent 9 traded 1 resource with Agent 1! Payoff: 41.0
# Agent 0 traded 1 resource with Agent 9! Payoff: 49.5
# Agent 1 acquired a resource! Total resources: 13, Payoff: 37.5
# Agent 5 traded 1 resource with Agent 7! Payoff: 50.0
# Agent 7 acquired a resource! Total resources: 49, Payoff: 65.0
# Agent 2 traded 1 resource with Agent 5! Payoff: 35.5
# Remaining available resources: 296
# Step 98
# Agent 5 traded 1 resource with Agent 1! Payoff: 50.5
# Agent 3 acquired a resource! Total resources: 15, Payoff: 31.5
# Agent 8 traded 1 resource with Agent 0! Payoff: 32.5
# Agent 0 traded 1 resource with Agent 9! Payoff: 50.0
# Agent 9 acquired a resource! Total resources: 22, Payoff: 44.0
# Agent 2 acquired a resource! Total resources: 14, Payoff: 36.5
# Remaining available resources: 293
# Step 99
# Agent 0 traded 1 resource with Agent 9! Payoff: 49.5
# Agent 1 traded 1 resource with Agent 3! Payoff: 38.0
# Agent 5 acquired a resource! Total resources: 33, Payoff: 51.5
# Agent 6 traded 1 resource with Agent 8! Payoff: 41.5
# Agent 3 acquired a resource! Total resources: 17, Payoff: 33.5
# Agent 7 traded 1 resource with Agent 3! Payoff: 64.5
# Agent 4 acquired a resource! Total resources: 13, Payoff: 31.5
# Agent 8 traded 1 resource with Agent 4! Payoff: 33.0
# Remaining available resources: 290
# Step 100
# Agent 6 traded 1 resource with Agent 4! Payoff: 41.0
# Agent 0 traded 1 resource with Agent 5! Payoff: 49.0
# Agent 7 traded 1 resource with Agent 2! Payoff: 64.0
# Agent 9 traded 1 resource with Agent 4! Payoff: 44.5
# Agent 8 acquired a resource! Total resources: 12, Payoff: 34.0
# Agent 2 traded 1 resource with Agent 6! Payoff: 37.0
# Agent 1 traded 1 resource with Agent 9! Payoff: 37.5
# Remaining available resources: 289
# Step 101
# Agent 9 traded 1 resource with Agent 7! Payoff: 45.0
# Agent 7 acquired a resource! Total resources: 49, Payoff: 66.0
# Agent 0 acquired a resource! Total resources: 27, Payoff: 50.0
# Agent 6 acquired a resource! Total resources: 20, Payoff: 43.0
# Agent 5 traded 1 resource with Agent 8! Payoff: 52.0
# Agent 3 traded 1 resource with Agent 6! Payoff: 34.0
# Agent 1 acquired a resource! Total resources: 13, Payoff: 38.5
# Remaining available resources: 285
# Step 102
# Agent 3 traded 1 resource with Agent 6! Payoff: 33.5
# Agent 4 traded 1 resource with Agent 9! Payoff: 34.0
# Agent 9 traded 1 resource with Agent 4! Payoff: 45.5
# Agent 2 traded 1 resource with Agent 5! Payoff: 36.5
# Agent 5 acquired a resource! Total resources: 35, Payoff: 54.0
# Agent 8 traded 1 resource with Agent 2! Payoff: 34.5
# Remaining available resources: 284
# Step 103
# Agent 7 traded 1 resource with Agent 2! Payoff: 65.5
# Agent 3 traded 1 resource with Agent 6! Payoff: 33.0
# Agent 8 traded 1 resource with Agent 1! Payoff: 34.0
# Agent 9 traded 1 resource with Agent 2! Payoff: 45.0
# Agent 0 traded 1 resource with Agent 3! Payoff: 49.5
# Agent 6 traded 1 resource with Agent 9! Payoff: 45.5
# Agent 2 traded 1 resource with Agent 7! Payoff: 39.0
# Agent 1 traded 1 resource with Agent 4! Payoff: 39.0
# Remaining available resources: 284
# Step 104
# Agent 3 acquired a resource! Total resources: 17, Payoff: 35.0
# Agent 1 acquired a resource! Total resources: 14, Payoff: 40.0
# Agent 2 traded 1 resource with Agent 1! Payoff: 38.5
# Agent 0 traded 1 resource with Agent 8! Payoff: 49.0
# Agent 5 traded 1 resource with Agent 4! Payoff: 53.5
# Agent 8 acquired a resource! Total resources: 13, Payoff: 36.0
# Agent 7 traded 1 resource with Agent 1! Payoff: 66.0
# Agent 9 acquired a resource! Total resources: 23, Payoff: 47.0
# Agent 4 traded 1 resource with Agent 2! Payoff: 36.5
# Remaining available resources: 280
# Step 105
# Agent 6 traded 1 resource with Agent 9! Payoff: 45.0
# ...
# Agent 2 traded 1 resource with Agent 4! Payoff: 219.5
# Agent 9 attempted to acquire a resource but none are available.
# Agent 9 traded 1 resource with Agent 1! Payoff: 211.5
# Agent 3 traded 1 resource with Agent 2! Payoff: 192.0
# Remaining available resources: 0
# Step 477
# Agent 6 attempted to acquire a resource but none are available.
# Agent 6 traded 1 resource with Agent 5! Payoff: 215.5
# Agent 9 traded 1 resource with Agent 7! Payoff: 211.0
# Agent 7 traded 1 resource with Agent 6! Payoff: 227.0
# Agent 0 attempted to acquire a resource but none are available.
# Agent 1 traded 1 resource with Agent 6! Payoff: 204.0
# Agent 8 attempted to acquire a resource but none are available.
# Agent 8 traded 1 resource with Agent 5! Payoff: 199.5
# Agent 2 traded 1 resource with Agent 7! Payoff: 220.0
# Agent 3 traded 1 resource with Agent 6! Payoff: 191.5
# Agent 5 traded 1 resource with Agent 1! Payoff: 217.5
# Agent 4 traded 1 resource with Agent 5! Payoff: 233.0
# Remaining available resources: 0
# Step 478
# Agent 4 attempted to acquire a resource but none are available.
# Agent 4 traded 1 resource with Agent 0! Payoff: 232.5
# Agent 8 traded 1 resource with Agent 3! Payoff: 199.0
# Agent 0 traded 1 resource with Agent 4! Payoff: 234.0
# Agent 2 traded 1 resource with Agent 6! Payoff: 219.5
# Agent 1 traded 1 resource with Agent 9! Payoff: 204.5
# Agent 6 traded 1 resource with Agent 9! Payoff: 219.0
# Agent 5 traded 1 resource with Agent 9! Payoff: 218.0
# Agent 7 traded 1 resource with Agent 1! Payoff: 227.5
# Agent 9 traded 1 resource with Agent 5! Payoff: 213.5
# Remaining available resources: 0
# Step 479
# Agent 8 traded 1 resource with Agent 3! Payoff: 198.5
# Agent 7 traded 1 resource with Agent 2! Payoff: 227.0
# Agent 2 traded 1 resource with Agent 9! Payoff: 220.0
# Agent 5 traded 1 resource with Agent 2! Payoff: 218.5
# Agent 1 traded 1 resource with Agent 2! Payoff: 205.0
# Agent 6 traded 1 resource with Agent 8! Payoff: 218.5
# Agent 9 attempted to acquire a resource but none are available.
# Agent 9 traded 1 resource with Agent 5! Payoff: 214.0
# Agent 0 traded 1 resource with Agent 9! Payoff: 233.5
# Remaining available resources: 0
# Step 480
# Agent 1 attempted to acquire a resource but none are available.
# Agent 1 traded 1 resource with Agent 5! Payoff: 204.5
# Agent 2 traded 1 resource with Agent 4! Payoff: 221.5
# Agent 9 traded 1 resource with Agent 0! Payoff: 214.5
# Agent 4 attempted to acquire a resource but none are available.
# Agent 4 traded 1 resource with Agent 3! Payoff: 234.0
# Agent 7 traded 1 resource with Agent 9! Payoff: 226.5
# Agent 8 traded 1 resource with Agent 9! Payoff: 199.0
# Agent 0 traded 1 resource with Agent 2! Payoff: 234.0
# Agent 6 traded 1 resource with Agent 9! Payoff: 218.0
# Agent 5 traded 1 resource with Agent 2! Payoff: 220.0
# Remaining available resources: 0
# Step 481
# Agent 7 traded 1 resource with Agent 3! Payoff: 226.0
# Agent 9 traded 1 resource with Agent 6! Payoff: 217.0
# Agent 3 attempted to acquire a resource but none are available.
# Agent 3 traded 1 resource with Agent 9! Payoff: 195.0
# Agent 6 traded 1 resource with Agent 3! Payoff: 218.5
# Agent 4 traded 1 resource with Agent 7! Payoff: 233.5
# Agent 1 traded 1 resource with Agent 9! Payoff: 204.0
# Agent 2 traded 1 resource with Agent 6! Payoff: 223.0
# Agent 5 traded 1 resource with Agent 1! Payoff: 219.5
# Agent 0 traded 1 resource with Agent 7! Payoff: 233.5
# Agent 8 attempted to acquire a resource but none are available.
# Agent 8 traded 1 resource with Agent 5! Payoff: 198.5
# Remaining available resources: 0
# Step 482
# Agent 0 traded 1 resource with Agent 8! Payoff: 233.0
# Agent 1 traded 1 resource with Agent 9! Payoff: 204.5
# Agent 2 attempted to acquire a resource but none are available.
# Agent 2 traded 1 resource with Agent 0! Payoff: 222.5
# Agent 7 attempted to acquire a resource but none are available.
# Agent 7 traded 1 resource with Agent 2! Payoff: 227.5
# Agent 9 attempted to acquire a resource but none are available.
# Agent 8 traded 1 resource with Agent 3! Payoff: 199.0
# Agent 6 attempted to acquire a resource but none are available.
# Agent 6 traded 1 resource with Agent 4! Payoff: 219.0
# Agent 5 attempted to acquire a resource but none are available.
# Agent 5 traded 1 resource with Agent 8! Payoff: 220.0
# Agent 4 traded 1 resource with Agent 5! Payoff: 234.0
# Remaining available resources: 0
# Step 483
# Agent 3 traded 1 resource with Agent 0! Payoff: 196.5
# Agent 4 traded 1 resource with Agent 6! Payoff: 233.5
# Agent 6 traded 1 resource with Agent 8! Payoff: 219.5
# Agent 8 traded 1 resource with Agent 3! Payoff: 200.5
# Agent 2 traded 1 resource with Agent 5! Payoff: 223.0
# Agent 1 traded 1 resource with Agent 2! Payoff: 204.0
# Agent 9 attempted to acquire a resource but none are available.
# Agent 9 traded 1 resource with Agent 6! Payoff: 219.5
# Agent 5 traded 1 resource with Agent 8! Payoff: 221.5
# Agent 0 attempted to acquire a resource but none are available.
# Agent 0 traded 1 resource with Agent 1! Payoff: 234.5
# Remaining available resources: 0
# Step 484
# Agent 6 traded 1 resource with Agent 8! Payoff: 220.0
# Agent 2 traded 1 resource with Agent 9! Payoff: 223.5
# Agent 0 traded 1 resource with Agent 6! Payoff: 234.0
# Agent 9 traded 1 resource with Agent 2! Payoff: 220.0
# Agent 1 traded 1 resource with Agent 6! Payoff: 204.5
# Agent 4 traded 1 resource with Agent 9! Payoff: 233.0
# Agent 3 attempted to acquire a resource but none are available.
# Agent 3 traded 1 resource with Agent 2! Payoff: 197.0
# Agent 8 traded 1 resource with Agent 7! Payoff: 202.0
# Agent 5 traded 1 resource with Agent 3! Payoff: 221.0
# Remaining available resources: 0
# Step 485
# Agent 1 traded 1 resource with Agent 2! Payoff: 204.0
# Agent 0 traded 1 resource with Agent 3! Payoff: 233.5
# Agent 7 traded 1 resource with Agent 8! Payoff: 228.0
# Agent 2 traded 1 resource with Agent 6! Payoff: 226.0
# Agent 9 traded 1 resource with Agent 0! Payoff: 220.5
# Agent 5 traded 1 resource with Agent 1! Payoff: 220.5
# Agent 4 traded 1 resource with Agent 9! Payoff: 232.5
# Agent 3 traded 1 resource with Agent 5! Payoff: 198.5
# Agent 8 traded 1 resource with Agent 7! Payoff: 202.5
# Remaining available resources: 0
# Step 486
# Agent 1 attempted to acquire a resource but none are available.
# Agent 1 traded 1 resource with Agent 4! Payoff: 204.5
# Agent 8 traded 1 resource with Agent 6! Payoff: 202.0
# Agent 0 attempted to acquire a resource but none are available.
# Agent 0 traded 1 resource with Agent 8! Payoff: 234.0
# Agent 5 traded 1 resource with Agent 4! Payoff: 221.0
# Agent 6 attempted to acquire a resource but none are available.
# Agent 6 traded 1 resource with Agent 3! Payoff: 223.5
# Agent 7 traded 1 resource with Agent 1! Payoff: 228.5
# Agent 3 traded 1 resource with Agent 4! Payoff: 199.0
# Agent 9 attempted to acquire a resource but none are available.
# Agent 9 traded 1 resource with Agent 6! Payoff: 221.0
# Agent 2 attempted to acquire a resource but none are available.
# Agent 2 traded 1 resource with Agent 6! Payoff: 225.5
# Agent 4 traded 1 resource with Agent 5! Payoff: 235.0
# Remaining available resources: 0
# Step 487
# Agent 5 attempted to acquire a resource but none are available.
# Agent 5 traded 1 resource with Agent 8! Payoff: 221.5
# Agent 0 traded 1 resource with Agent 2! Payoff: 233.5
# Agent 2 traded 1 resource with Agent 3! Payoff: 226.0
# Agent 6 traded 1 resource with Agent 8! Payoff: 225.0
# Agent 9 traded 1 resource with Agent 2! Payoff: 220.5
# Agent 3 traded 1 resource with Agent 0! Payoff: 199.5
# Agent 8 attempted to acquire a resource but none are available.
# Agent 8 traded 1 resource with Agent 7! Payoff: 204.5
# Agent 1 traded 1 resource with Agent 0! Payoff: 205.0
# Agent 4 attempted to acquire a resource but none are available.
# Agent 4 traded 1 resource with Agent 5! Payoff: 234.5
# Agent 7 attempted to acquire a resource but none are available.
# Agent 7 traded 1 resource with Agent 9! Payoff: 229.0
# Remaining available resources: 0
# Step 488
# Agent 2 traded 1 resource with Agent 8! Payoff: 226.5
# Agent 0 attempted to acquire a resource but none are available.
# Agent 0 traded 1 resource with Agent 4! Payoff: 235.0
# Agent 4 traded 1 resource with Agent 9! Payoff: 235.0
# Agent 6 traded 1 resource with Agent 9! Payoff: 224.5
# Agent 5 traded 1 resource with Agent 3! Payoff: 222.0
# Agent 3 traded 1 resource with Agent 1! Payoff: 200.0
# Agent 9 traded 1 resource with Agent 4! Payoff: 223.0
# Remaining available resources: 0
# Step 489
# Agent 0 traded 1 resource with Agent 7! Payoff: 234.5
# Agent 2 traded 1 resource with Agent 7! Payoff: 226.0
# Agent 6 traded 1 resource with Agent 0! Payoff: 224.0
# Agent 7 traded 1 resource with Agent 8! Payoff: 230.5
# Agent 8 traded 1 resource with Agent 0! Payoff: 206.0
# Agent 1 traded 1 resource with Agent 5! Payoff: 205.5
# Agent 9 traded 1 resource with Agent 2! Payoff: 222.5
# Remaining available resources: 0
# Step 490
# Agent 2 traded 1 resource with Agent 3! Payoff: 226.5
# Agent 1 traded 1 resource with Agent 2! Payoff: 205.0
# Agent 8 traded 1 resource with Agent 0! Payoff: 205.5
# Agent 7 traded 1 resource with Agent 2! Payoff: 230.0
# Agent 9 traded 1 resource with Agent 8! Payoff: 222.0
# Agent 4 attempted to acquire a resource but none are available.
# Agent 4 traded 1 resource with Agent 6! Payoff: 235.5
# Agent 3 attempted to acquire a resource but none are available.
# Agent 3 traded 1 resource with Agent 9! Payoff: 200.5
# Agent 5 traded 1 resource with Agent 1! Payoff: 222.5
# Remaining available resources: 0
# Step 491
# Agent 6 traded 1 resource with Agent 8! Payoff: 224.5
# Agent 7 traded 1 resource with Agent 4! Payoff: 229.5
# Agent 2 traded 1 resource with Agent 3! Payoff: 228.0
# Agent 5 traded 1 resource with Agent 2! Payoff: 222.0
# Agent 1 traded 1 resource with Agent 7! Payoff: 205.5
# Agent 9 attempted to acquire a resource but none are available.
# Agent 4 traded 1 resource with Agent 6! Payoff: 236.0
# Agent 0 traded 1 resource with Agent 9! Payoff: 237.0
# Agent 8 traded 1 resource with Agent 5! Payoff: 207.0
# Remaining available resources: 0
# Step 492
# Agent 7 traded 1 resource with Agent 6! Payoff: 230.0
# Agent 6 attempted to acquire a resource but none are available.
# Agent 6 traded 1 resource with Agent 2! Payoff: 226.0
# Agent 5 traded 1 resource with Agent 4! Payoff: 222.5
# Agent 0 attempted to acquire a resource but none are available.
# Agent 0 traded 1 resource with Agent 7! Payoff: 236.5
# Agent 3 traded 1 resource with Agent 4! Payoff: 201.0
# Agent 4 traded 1 resource with Agent 9! Payoff: 237.5
# Agent 9 traded 1 resource with Agent 5! Payoff: 224.5
# Agent 8 attempted to acquire a resource but none are available.
# Agent 8 traded 1 resource with Agent 6! Payoff: 206.5
# Agent 2 traded 1 resource with Agent 6! Payoff: 229.5
# Agent 1 traded 1 resource with Agent 5! Payoff: 205.0
# Remaining available resources: 0
# Step 493
# Agent 1 attempted to acquire a resource but none are available.
# Agent 8 traded 1 resource with Agent 3! Payoff: 206.0
# Agent 6 traded 1 resource with Agent 8! Payoff: 227.5
# Agent 3 traded 1 resource with Agent 0! Payoff: 201.5
# Agent 2 traded 1 resource with Agent 6! Payoff: 229.0
# Agent 7 traded 1 resource with Agent 6! Payoff: 230.5
# Agent 0 traded 1 resource with Agent 4! Payoff: 237.0
# Agent 9 traded 1 resource with Agent 7! Payoff: 224.0
# Agent 4 traded 1 resource with Agent 9! Payoff: 238.0
# Agent 5 traded 1 resource with Agent 3! Payoff: 224.0
# Remaining available resources: 0
# Step 494
# Agent 8 traded 1 resource with Agent 7! Payoff: 206.5
# Agent 2 traded 1 resource with Agent 6! Payoff: 228.5
# Agent 7 attempted to acquire a resource but none are available.
# Agent 7 traded 1 resource with Agent 9! Payoff: 232.0
# Agent 0 traded 1 resource with Agent 8! Payoff: 236.5
# Agent 5 attempted to acquire a resource but none are available.
# Agent 6 traded 1 resource with Agent 8! Payoff: 230.0
# Agent 9 traded 1 resource with Agent 6! Payoff: 225.5
# Agent 3 traded 1 resource with Agent 6! Payoff: 202.0
# Agent 1 traded 1 resource with Agent 6! Payoff: 204.5
# Agent 4 traded 1 resource with Agent 9! Payoff: 237.5
# Remaining available resources: 0
# Step 495
# Agent 0 attempted to acquire a resource but none are available.
# Agent 0 traded 1 resource with Agent 3! Payoff: 236.0
# Agent 9 traded 1 resource with Agent 3! Payoff: 226.0
# Agent 7 traded 1 resource with Agent 2! Payoff: 231.5
# Agent 6 traded 1 resource with Agent 2! Payoff: 232.5
# Agent 1 traded 1 resource with Agent 3! Payoff: 204.0
# Agent 2 traded 1 resource with Agent 9! Payoff: 230.0
# Agent 8 traded 1 resource with Agent 2! Payoff: 208.0
# Agent 5 traded 1 resource with Agent 3! Payoff: 223.5
# Agent 4 traded 1 resource with Agent 2! Payoff: 237.0
# Agent 3 traded 1 resource with Agent 8! Payoff: 205.5
# Remaining available resources: 0
# Step 496
# Agent 4 attempted to acquire a resource but none are available.
# Agent 4 traded 1 resource with Agent 3! Payoff: 236.5
# Agent 6 attempted to acquire a resource but none are available.
# Agent 6 traded 1 resource with Agent 0! Payoff: 232.0
# Agent 7 attempted to acquire a resource but none are available.
# Agent 7 traded 1 resource with Agent 8! Payoff: 231.0
# Agent 9 attempted to acquire a resource but none are available.
# Agent 9 traded 1 resource with Agent 3! Payoff: 226.5
# Agent 2 attempted to acquire a resource but none are available.
# Agent 2 traded 1 resource with Agent 4! Payoff: 231.5
# Agent 8 traded 1 resource with Agent 3! Payoff: 209.5
# Agent 1 attempted to acquire a resource but none are available.
# Agent 1 traded 1 resource with Agent 6! Payoff: 203.5
# Agent 3 traded 1 resource with Agent 2! Payoff: 208.0
# Agent 5 traded 1 resource with Agent 4! Payoff: 223.0
# Remaining available resources: 0
# Step 497
# Agent 3 attempted to acquire a resource but none are available.
# Agent 3 traded 1 resource with Agent 9! Payoff: 207.5
# Agent 4 traded 1 resource with Agent 9! Payoff: 238.0
# Agent 9 traded 1 resource with Agent 4! Payoff: 228.0
# Agent 6 traded 1 resource with Agent 9! Payoff: 232.5
# Agent 8 traded 1 resource with Agent 6! Payoff: 209.0
# Agent 0 traded 1 resource with Agent 1! Payoff: 236.5
# Agent 7 traded 1 resource with Agent 1! Payoff: 230.5
# Agent 5 traded 1 resource with Agent 0! Payoff: 222.5
# Remaining available resources: 0
# Step 498
# Agent 3 traded 1 resource with Agent 0! Payoff: 207.0
# Agent 6 traded 1 resource with Agent 2! Payoff: 233.0
# Agent 4 traded 1 resource with Agent 2! Payoff: 238.5
# Agent 0 traded 1 resource with Agent 6! Payoff: 238.0
# Agent 8 attempted to acquire a resource but none are available.
# Agent 8 traded 1 resource with Agent 3! Payoff: 208.5
# Agent 1 traded 1 resource with Agent 3! Payoff: 205.0
# Agent 7 traded 1 resource with Agent 6! Payoff: 230.0
# Agent 9 traded 1 resource with Agent 8! Payoff: 228.5
# Agent 2 traded 1 resource with Agent 3! Payoff: 234.0
# Agent 5 traded 1 resource with Agent 4! Payoff: 222.0
# Remaining available resources: 0
# Step 499
# Agent 5 traded 1 resource with Agent 0! Payoff: 221.5
# Agent 6 traded 1 resource with Agent 7! Payoff: 234.5
# Agent 0 traded 1 resource with Agent 6! Payoff: 238.5
# Agent 9 traded 1 resource with Agent 5! Payoff: 228.0
# Agent 3 traded 1 resource with Agent 6! Payoff: 209.5
# Agent 4 traded 1 resource with Agent 9! Payoff: 239.0
# Agent 8 traded 1 resource with Agent 7! Payoff: 209.0
# Agent 2 traded 1 resource with Agent 0! Payoff: 233.5
# Agent 1 traded 1 resource with Agent 0! Payoff: 204.5
# Remaining available resources: 0
# Step 500
# Agent 1 traded 1 resource with Agent 8! Payoff: 204.0
# Agent 8 traded 1 resource with Agent 1! Payoff: 209.5
# Agent 0 traded 1 resource with Agent 2! Payoff: 240.0
# Agent 3 attempted to acquire a resource but none are available.
# Agent 3 traded 1 resource with Agent 6! Payoff: 209.0
# Agent 9 traded 1 resource with Agent 3! Payoff: 228.5
# Agent 6 traded 1 resource with Agent 7! Payoff: 237.0
# Agent 4 attempted to acquire a resource but none are available.
# Agent 4 traded 1 resource with Agent 6! Payoff: 238.5
# Agent 5 attempted to acquire a resource but none are available.
# Agent 5 traded 1 resource with Agent 2! Payoff: 222.0
# Agent 2 attempted to acquire a resource but none are available.
# Agent 2 traded 1 resource with Agent 4! Payoff: 235.0
# Agent 7 traded 1 resource with Agent 0! Payoff: 232.5
# Remaining available resources: 0

# %%
# Collect the number of resources acquired by each agent
resources_acquired = [agent.resources_acquired for agent in model.schedule.agents]

# Create bins for agents (0 to N-1)
agents = list(range(model.num_agents))

# Plotting the histogram of resources acquired by each agent
plt.bar(agents, resources_acquired, color='blue', edgecolor='black')
plt.xticks(agents)  # Set x-ticks to agent numbers
plt.xlabel('Agent Number')
plt.ylabel('Number of Resources Acquired')
plt.title('Resources Acquired by Each Agent')
plt.grid(axis='y')
plt.show()

# %%
# Print out the final payoffs of each agent
print("\nFinal Payoffs of Each Agent:")
for agent in model.schedule.agents:
    print(f"Agent {agent.unique_id}: Payoff: {agent.payoff}")
# Out:
# Final Payoffs of Each Agent:
# Agent 1: Payoff: 205.0
# Agent 8: Payoff: 209.5
# Agent 0: Payoff: 241.0
# Agent 3: Payoff: 210.0
# Agent 9: Payoff: 228.5
# Agent 6: Payoff: 238.0
# Agent 4: Payoff: 239.5
# Agent 5: Payoff: 222.0
# Agent 2: Payoff: 235.0
# Agent 7: Payoff: 232.5
